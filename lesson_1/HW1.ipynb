# %% [markdown]
# # Домашняя работа 1
#
# В этой домашней работе нужно закрепить материал первого занятия: переменные, строки, списки, циклы, словари, функции и первый взгляд на таблицы.
#
# Как работать с ноутбуком:
#
# 1. Запустите ячейку с исходными данными.
# 2. В каждой задаче напишите код в пустой ячейке ниже условия.
# 3. Выведите ответ через `print()` или последней строкой ячейки.
# 4. Скопируйте получившийся ответ в Stepik и получите заветный балл ≽^•⩊•^≼
#
# `Можно ли использовать ИИ?`: ИИ использовать при решении дз *допустимо*, однако важно использовать инструмент как помощника для объяснения. **Ни в коем случае не копипастите решение полностью, ведь так вы ничему не научитесь.**

# %% [markdown]
# ## Исходные данные
#
# В задачах используется небольшой список объявлений о продаже квартир. Каждое объявление хранится как словарь.

# %%
listings = [
    {'city': 'Махачкала', 'district': 'Советский район', 'price': 7_500_000, 'area': 54.3, 'rooms': 2, 'floor': 7},
    {'city': 'Каспийск', 'district': 'Центр', 'price': 6_200_000, 'area': 42.0, 'rooms': 1, 'floor': 3},
    {'city': 'Махачкала', 'district': 'Ленинский район', 'price': 8_100_000, 'area': 61.5, 'rooms': 3, 'floor': 9},
    {'city': 'Дербент', 'district': 'Старый город', 'price': 5_900_000, 'area': 38.2, 'rooms': 1, 'floor': 2},
    {'city': 'Каспийск', 'district': 'Приморский район', 'price': 9_300_000, 'area': 70.0, 'rooms': 3, 'floor': 6},
    {'city': 'Махачкала', 'district': 'Редукторный', 'price': 6_850_000, 'area': 48.5, 'rooms': 2, 'floor': 5},
]

listings

# %% [markdown]
# ## Задание 1
#
# Выведите количество объявлений в списке `listings`.
#
# В Stepik введите одно число.

# %%
# ваш классный код здесь

# %% [markdown]
# ## Задание 2
#
# Выведите город первого (помните, что счет от 0) объявления.
#
# В Stepik введите название города без кавычек.

# %%
# ваш классный код здесь

# %% [markdown]
# ## Задание 3
#
# Посчитайте цену за квадратный метр для первого объявления. Округлите результат с помощью `round()`.
#
# В Stepik введите одно целое число.

# %%
# ваш классный код здесь

# %% [markdown]
# ## Задание 4
#
# Создайте список `prices`, в котором будут только цены всех объявлений. Выведите минимальную цену.
#
# В Stepik введите одно число без пробелов.

# %%
# объявим перменную
prices = []

# запустим цикл и пройдемся 
# добавляя в список только цены
for listing in listings:
    prices.append(listing[])  # впишите что нужно добавлять в список

# %%
# осталось найти минимум:

# %% [markdown]
# ## Задание 5
#
# Посчитайте среднюю площадь квартир. Ответ округлите до одного знака после запятой.
#
# В Stepik введите число, например 209.4567 мы окргуляем до 209.4

# %%
# объявим перменную
all_areas = []

# запустим цикл и пройдемся по объявлениям, 
# добавляя в наш список только площадь
for listing in listings:
    # допишите цикл

# %%
# осталось найти среднее: поделим сумму площадей на их количество

# %% [markdown]
# ## Задание 6
#
# Найдите все объявления с количеством комнат `2` или больше. Выведите количество таких объявлений.
#
# В Stepik введите одно число.

# %%
# объявим перменную
two_rooms_and_more = []

# запустим цикл и пройдемся по объявлениям, 
# добавляя в наш список только те обявления,
# в которых комнат больше или равно 2
for listing in listings:
    if # допишите условие и не забудьте двоеточие в конце
        two_rooms_and_more.append(listing)  # вкладываем объявление

# %%
# а теперь посмотрим сколько таких объявлений у нас есть:
len(two_rooms_and_more)

# %% [markdown]
# ## Задание 7
#
# Создайте множество городов, которые встречаются в объявлениях. Выведите количество уникальных городов.
#
# В Stepik введите одно число.

# %%
# объявим перменную - множество
cities = set()

# запустим цикл и пройдемся по объявлениям, 
# добавляя в наше множество только города
for listing in listings:
    # допишите цикл, используя метод add()

# %%
# а теперь посмотрим сколько таких объявлений у нас есть:
len(cities)

# %% [markdown]
# ## Задание 8
#
# Есть строка с названием района. Уберите лишние пробелы по краям и приведите строку к нижнему регистру.
#
# Выведите обработанную строку без кавычек. В Stepik введите строку без кавычек

# %%
district_name = '  Советский район  '

# ваш классный код здесь

# %% [markdown]
# ## Задание 9
#
# Напишите функцию `price_per_square_meter(price, area)`, которая возвращает цену за квадратный метр.
#
# Затем вызовите функцию для цены `6_200_000` и площади `42.0`. Ответ округлите с помощью `round()` и выведите.
#
# В Stepik введите одно целое число.

# %%
# объявляем функцию
# она принимает два параметра: цену и площадь 

def price_per_square_meter(price, area):
    # ваш код здесь
    result =

    return result

# %%
my_price = price_per_square_meter()  # введите параметры из условия задачи
print(round(my_price))

# %% [markdown]
# ## Задание 10
#
# Напишите функцию `is_expensive(listing, threshold)`, которая возвращает `True`, если цена объявления выше порога `threshold`, и `False` иначе.
#
# Проверьте функцию на последнем объявлении из `listings` с порогом `7_000_000`. Выведите результат.
#
# В Stepik введите `True` или `False`.

# %%
# объявляем функцию
# она принимает два параметра: объявление и порог 

def is_expensive(listing, threshold):
    # ваш код здесь
    if # допишите условие
        return True
    else:
        return False

# %%
# вызовите функцию по условию выше
print(is_expensive())

# %% [markdown]
# ## Задание 11
#
# Создайте словарь, где ключ — город, а значение — количество объявлений в этом городе.
#
# Выведите количество объявлений для города `Махачкала`.
#
# В Stepik введите одно число.

# %%
# дополните код

# инициализируем словарь
my_dict = {}

# заводим цикл
for listing in listings:
    # для удобства сразу укажем город
    city = listing['city']

    # допишите условие- если города нет в словаре, 
    # то в качестве ключа будет стоять единица 
    if 
        my_dict[city] = 1
    # иначе - добавляем единицу к текущему счетчику
    else:
        my_dict[city] = my_dict[city] + 1

print(my_dict)

# %%
# осталось вывести значение по ключу 'Махачкала'

# %% [markdown]
# ## Задание 12
#
# Минимально познакомимся с `pandas`. Превратите `listings` в таблицу `DataFrame` и посчитайте среднюю цену по городам.
#
# Выведите среднюю цену для города `Каспийск`, округлённую до целого числа - методом `round()`.
#
# В Stepik введите одно число без пробелов.

# %%
import pandas as pd

# %%
listings = pd.DataFrame()  # допишите код
listings

# %%
# подсказка: надо использовать методы .groupby() и .mean()
round(listings.groupby('')[''].mean())
